# %%
from dotenv import load_dotenv
from pydantic import BaseModel, GetJsonSchemaHandler
from pydantic.json_schema import JsonSchemaValue
from typing import Any, Optional
import pandas as pd
import matplotlib.pyplot as plt
from langchain_openai import ChatOpenAI
from langchain.agents import tool
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.agents.format_scratchpad.openai_tools import (
    format_to_openai_tool_messages,
)
from langchain.agents.output_parsers.openai_tools import OpenAIToolsAgentOutputParser
from langchain.agents import AgentExecutor
from langchain_core.prompts import MessagesPlaceholder
from langchain_core.messages import AIMessage, HumanMessage
from autogen_agentchat.teams import RoundRobinGroupChat


load_dotenv()

from fast_flights import FlightData, Passengers, Result, get_flights
from pprint import pprint
import requests
import os

# %%
from fast_flights import FlightData, Passengers, Result, get_flights
from pprint import pprint

result: Result = get_flights(
    flight_data=[
        FlightData(date="2025-05-01", from_airport="PHL", to_airport="PHX")
    ],
    trip="one-way",
    seat="economy",
    passengers=Passengers(adults=2, children=1, infants_in_seat=0, infants_on_lap=0),
    fetch_mode="fallback",
)

def format_flight(flight: FlightData):
    return {
        "name": flight.name,
        "departure": flight.departure,
        "arrival": flight.arrival,
        "duration": flight.duration,
        "stops": flight.stops,
        "price": flight.price
    }
pprint([format_flight(flight) for flight in result.flights if flight.is_best])

# The price is currently... low/typical/high
print("The price is currently", result.current_price)
# Out:
# [{'arrival': '2:06 PM on Thu, May 1',
#   'departure': '5:15 AM on Thu, May 1',
#   'duration': '11 hr 51 min',
#   'name': 'Frontier',
#   'price': '$374',
#   'stops': 1},
#  {'arrival': '1:28 PM on Fri, May 2',
#   'departure': '10:08 PM on Thu, May 1',
#   'duration': '18 hr 20 min',
#   'name': 'Self transferThis trip includes tickets from multiple airlines. '
#           'Missed connections may be protected by the booking provider.',
#   'price': '$380',
#   'stops': 1},
#  {'arrival': '11:42 AM on Thu, May 1',
#   'departure': '9:27 AM on Thu, May 1',
#   'duration': '5 hr 15 min',
#   'name': 'American',
#   'price': '$866',
#   'stops': 0},
#  {'arrival': '9:25 AM on Thu, May 1',
#   'departure': '5:50 AM on Thu, May 1',
#   'duration': '6 hr 35 min',
#   'name': 'Southwest',
#   'price': '$895',
#   'stops': 1}]
# The price is currently typical

# %%
import asyncio
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import SelectorGroupChat
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.ui import Console

# %%
model_client = OpenAIChatCompletionClient(model="gpt-4o-mini-2024-07-18")

# %%
async def lookup_hotel(city_code: str) -> str:
    # fetch access token
    token_url = "https://test.api.amadeus.com/v1/security/oauth2/token"
    client_id = os.getenv("AMADEUS_API_KEY")
    client_secret = os.getenv("AMADEUS_SECRET")
    print(client_id)
    print(client_secret)

    data = {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret
    }

    header = {
        "Content-Type": "application/x-www-form-urlencoded"
    }
    # Make the token request
    response = requests.post(token_url, data=data, headers=header)
    if response.status_code != 200:
        print("Failed to obtain access token:", response.status_code)
        print(response.text)
        return
    token_info = response.json()
    access_token = token_info['access_token']
    # print("Access Token:", access_token)

    #make hotel list request (collect all hotels in city)
    api = "https://test.api.amadeus.com"
    hotel_list = "/v1/reference-data/locations/hotels/by-city"
    hotel_offers = "/v3/shopping/hotel-offers"
    auth_header = {
        "Content-Type": "application/x-www-form-urlencoded",
        "Authorization": "Bearer " + access_token
    }

    params = {
        "cityCode": city_code
    }

    listings_in_city = requests.get(api+hotel_list, headers=auth_header, params=params).json()
    # print(listings_in_city)
    
    # hotel search for next requests
    
    hotel_search_params = [hotel["hotelId"] for hotel in listings_in_city["data"]]
    # print(hotel_search_params)
    responses = []
    inc = 50
    for i in range(0,len(hotel_search_params), inc):
        bound = min(i+inc, len(hotel_search_params))
        search = requests.get(api + hotel_offers, headers=auth_header, params = {"hotelIds": hotel_search_params[i:bound]}).json()
        # hotel_search_params
        # print(search)    
        if ("data" in search):
            responses += search["data"]

    # search = requests.get(api + hotel_offers, headers=auth_header, params = {"hotelIds": hotel_search_params[0:50]}).json()
    # print(search)
    # print(responses)
    out = [{"price": [p["price"]["total"] for p in r["offers"]], "name": r["hotel"]["name"]} for r in responses]
    # return out
    return f"Here are some hotels in {city_code}: ${out}" #{[c['name'] for c in out]}."

hotel_agent = AssistantAgent(
        "Hotel_Agent",
        model_client,
        tools=[lookup_hotel],
        description="Helps with hotel booking.",
        system_message="""
        You are a hotel search agent.
        Your only tool is lookup_hotel - this tool only accepts the city code in IATA format (airport codes).
        You only make one search at a time.
        You return the options for hotel as returned by the lookup_hotel function tool for the user to choose from. Try to diversify based on price.
        """
    )

# %%
from fast_flights import FlightData, Passengers, Result, get_flights

def format_flight(flight: FlightData):
    return {
        "name": flight.name,
        "departure": flight.departure,
        "arrival": flight.arrival,
        "duration": flight.duration,
        "stops": flight.stops,
        "price": flight.price
    }


async def lookup_flight(departure_date: str, return_date: str, source_airport_code: str, destination_airport_code: str) -> str:
    leave_result: Result = get_flights(
    flight_data=[
            FlightData(date=departure_date, from_airport=source_airport_code, to_airport=destination_airport_code),
        ],
        trip="one-way",
        seat="economy",
        passengers=Passengers(adults=1, children=0, infants_in_seat=0, infants_on_lap=0),
        fetch_mode="fallback",
    )

    best_leave = format_flight([flight for flight in leave_result.flights if flight.is_best][0])

    return_result: Result = get_flights(
    flight_data=[
            FlightData(date=return_date, from_airport=destination_airport_code, to_airport=source_airport_code),
        ],
        trip="one-way",
        seat="economy",
        passengers=Passengers(adults=1, children=0, infants_in_seat=0, infants_on_lap=0),
        fetch_mode="fallback",
    )

    best_return = format_flight([flight for flight in return_result.flights if flight.is_best][0])

    res = f"Here is the best flight from {source_airport_code} to {destination_airport_code}:\n"
    for key in best_leave:
        res += f"{key}: {best_leave[key]}\n"
    res += f"Here is the best return flight from {destination_airport_code} to {source_airport_code}:\n"
    for key in best_return:
        res += f"{key}: {best_return[key]}\n"
    return res

print(await lookup_flight("2025-05-01", "2025-05-10", "PHL", "PHX"))

flight_agent = AssistantAgent(
    "Flight_Agent",
    model_client,
    tools=[lookup_flight],
    description="Helps with flight booking.",
    system_message="""
    You are a flight search agent.
    Your only tool is lookup_flight. This tool takes in a departure date in YYYY-MM-DD format, a return date in YYYY-MM-DD format, the source airport code, and the destination code, and returns .
    You may only make one search at a time.
    """
)
# Out:
# Here is the best flight from PHL to PHX:
# name: Frontier
# departure: 5:15 AM on Thu, May 1
# arrival: 2:06 PM on Thu, May 1
# duration: 11 hr 51 min
# stops: 1
# price: $125
# Here is the best return flight from PHX to PHL:
# name: Frontier
# departure: 9:35 AM on Sat, May 10
# arrival: 9:15 PM on Sat, May 10
# duration: 8 hr 40 min
# stops: 1
# price: $109

# %%
from autogen_agentchat.agents import UserProxyAgent

user_proxy = UserProxyAgent(
  name="User_Proxy_Agent",
  input_func=input
)

# %%
async def add(a: str, b:str) -> float:
        return float(a)+float(b)

budget_agent = AssistantAgent(
        "Budget_Agent",
        model_client,
        tools=[add],
        description="Helps with calculating total cost of the trip.",
        system_message="""
        You are a price estimating agent.
        You will add up the costs of the departure and return flights and the hotel cost.
        You will also provide an estimate of how much food and activities will cost for the duration of the trip.
        You will return the total projected cost of the trip, and provide a breakdown of the source of costs.
        """
)

# %%
google_api_key = os.environ.get("GOOGLE_API_KEY")

headers = {
    "X-Goog-Api-Key": google_api_key,
    "X-Goog-FieldMask": "places.displayName,places.formattedAddress,places.googleMapsLinks"
}

url = "https://places.googleapis.com/v1/places:searchText?"


async def lookup_excursion(location: str) -> str:
        data = {"textQuery": f"Excursions and activities near {location}"}
        res = requests.post(url, json=data, headers=headers).json()
        
        res_string = f"Here is a list of activities to do near {location}\n"
        for i, place in enumerate(res["places"]):
                res_string += f"{i + 1}) Activity Name: {place['displayName']['text']}; Address: {place['formattedAddress']}; Link: {place['googleMapsLinks']['placeUri']}\n"

        return res_string


async def lookup_food(location: str) -> str:
        data = {"textQuery": f"Food and restaurants near {location}"}
        res = requests.post(url, json=data, headers=headers).json()
        
        res_string = f"Here is a list of restaurants near {location}\n"
        for i, place in enumerate(res["places"]):
                res_string += f"{i + 1}) Activity Name: {place['displayName']['text']}; Address: {place['formattedAddress']}; Link: {place['googleMapsLinks']['placeUri']}\n"

        return res_string

excursion_agent = AssistantAgent(
        "Excursion_Agent",
        model_client,
        tools=[lookup_excursion, lookup_food],
        description="Helps with finding excursions and food.",
        system_message="""
        You are a flight search agent.
        Your only two tools are lookup_excursion - use it to find excursions near a location, and lookup_food - use it to find food near a location
        You may only make one search at a time.
        """
)

# %%
# async def book_trip() -> str:
#     return "Your trip is booked!"


travel_planning_agent = AssistantAgent(
    "TravelPlanningAgent",
    model_client=model_client,
    description="Helps with travel planning.",
    system_message="""
    You are a travel planning agent,
    Your job is to break down complex tasks into smaller, manageable substasks.
    Your team members are:
    Flight agent: searches for flights
    Hotel agent: searches for hotels
    Excursion agent: searches for activities and food, given a location
    User Proxy agent: confirms decisions with the user and asks clarifying questions

    You only plan and delegate tasks. You do not execute them yourself.
    After you have a list of hotels, prompt the user for which hotel they would prefer.
    After you have a list of excursions, prompt the user for which excursions they would prefer.
    After you have a list of restaurants, prompt the user for which restaurants they would prefer


    When assigning tasks, use this format:
    1. <agent> : <task>

    After all the tasks are complete, summarize the findings. You must construct an day-by-day itinerary. Each day must include at least lunch and dinner, and at least one excursion/activity.

    After building the day-by-day itinerary, Ask the user if they would like any other changes.
    """
)

"""
Flight: <Flight Data>
    ---<Date>---
    Breakfast: <Restaurant>
    Lunch: <Restaurant>
    Dinner: <Restaurant>

    Activities:
    <Activity 1>
    <Activity 2>
    <Activity 3>
    ...

    (repeat for all dates)

    Return Flight: <Flight Data>
"""



termination = TextMentionTermination("APPROVE")

team = SelectorGroupChat(
    [travel_planning_agent, hotel_agent, flight_agent, excursion_agent, user_proxy, budget_agent],
    model_client=model_client,
    termination_condition=termination,
)
await Console(team.run_stream(task="I live near New York City. Book me a 3 day trip in Los Angeles. I am leaving on 5/13/2025."))
# Out:
# ---------- user ----------
# I live near New York City. Book me a 3 day trip in Los Angeles. I am leaving on 5/13/2025.
# ---------- TravelPlanningAgent ----------
# Let's break down the trip planning into manageable tasks.
#
# ### Step 1: Search for Flights
# 1. Flight agent: Search for flights from New York City to Los Angeles for the departure date of 5/13/2025 and return on 5/16/2025.
#
# ### Step 2: Search for Hotels
# 2. Hotel agent: Search for hotels in Los Angeles for the dates of 5/13/2025 to 5/16/2025.
#
# ### Step 3: Search for Excursions and Food
# 3. Excursion agent: Search for activities and dining options in Los Angeles for the dates of 5/13/2025 to 5/16/2025.
#
# Once the tasks are complete, I'll confirm the choices with you. Let's get started!
# ---------- Flight_Agent ----------
# [FunctionCall(id='call_jTip6Iem8c5GWMGRKAUDTCgI', arguments='{"departure_date":"2025-05-13","return_date":"2025-05-16","source_airport_code":"JFK","destination_airport_code":"LAX"}', name='lookup_flight')]
# ---------- Flight_Agent ----------
# [FunctionExecutionResult(content='Here is the best flight from JFK to LAX:\nname: Frontier\ndeparture: 11:30 AM on Tue, May 13\narrival: 2:41 PM on Tue, May 13\nduration: 6 hr 11 min\nstops: 0\nprice: $89\nHere is the best return flight from LAX to JFK:\nname: Frontier\ndeparture: 8:50 PM on Fri, May 16\narrival: 5:30 AM on Sat, May 17\nduration: 5 hr 40 min\nstops: 0\nprice: $89\n', name='lookup_flight', call_id='call_jTip6Iem8c5GWMGRKAUDTCgI', is_error=False)]
# ---------- Flight_Agent ----------
# Here is the best flight from JFK to LAX:
# name: Frontier
# departure: 11:30 AM on Tue, May 13
# arrival: 2:41 PM on Tue, May 13
# duration: 6 hr 11 min
# stops: 0
# price: $89
# Here is the best return flight from LAX to JFK:
# name: Frontier
# departure: 8:50 PM on Fri, May 16
# arrival: 5:30 AM on Sat, May 17
# duration: 5 hr 40 min
# stops: 0
# price: $89
#
# DmLKsaZ4jk9cUoFPgBZvQVdXTRABlPdh
# zyGS6AQzNMt0oj50
# ---------- Hotel_Agent ----------
# [FunctionCall(id='call_nwvEPGZkR02jRwbJINeCEq92', arguments='{"city_code":"LAX"}', name='lookup_hotel')]
# ---------- Hotel_Agent ----------
# [FunctionExecutionResult(content="Here are some hotels in LAX: $[{'price': ['148.09'], 'name': 'Best Western Plus Thousand Oaks Inn'}, {'price': ['197.28'], 'name': 'Courtyard by Marriott Los Angeles Baldwin Park'}, {'price': ['312.58'], 'name': 'Courtyard by Marriott Los Angeles Century City Beverly Hills'}, {'price': ['219.50'], 'name': 'Courtyard by Marriott Los Angeles LAX Century Boulevard'}, {'price': ['178.18'], 'name': 'Courtyard by Marriott Los Angeles Pasadena Monrovia'}, {'price': ['219.61'], 'name': 'DOUBLETREE BY HILTON LOS ANGELES'}, {'price': ['214.69'], 'name': 'ES-LOS ANGELES INTL AP-SOU'}, {'price': ['210.90'], 'name': 'HILTON GARDEN INN MONTEBELLO'}, {'price': ['182.59'], 'name': 'HOLIDAY INN EXP STES WOODLAND'}, {'price': ['171.64'], 'name': 'Residence Inn by Marriott Anaheim Hills Yorba Linda'}, {'price': ['225.26'], 'name': 'Residence Inn by Marriott Redondo Beach'}, {'price': ['252.35'], 'name': 'Residence Inn by Marriott Los Angeles Westlake Village'}, {'price': ['484.73'], 'name': 'THE RITZ-CARLTON MARINA DEL RY'}, {'price': ['196.50'], 'name': 'The Westin Los Angeles Airport'}, {'price': ['184.19'], 'name': 'Best Western Plus Carriage Inn'}, {'price': ['215.88'], 'name': 'Courtyard by Marriott Los Angeles Westside'}, {'price': ['207.35'], 'name': 'Courtyard by Marriott Los Angeles Woodland Hills'}, {'price': ['196.37'], 'name': 'DBLTREE BY HILTON SAN PEDRO'}, {'price': ['241.84'], 'name': 'Fairfield Anaheim Resort'}, {'price': ['298.37'], 'name': 'HGI LOS ANGELES MARINA DEL REY'}, {'price': ['196.67'], 'name': 'HAMPTON INN SANTA CLARITA'}, {'price': ['219.52'], 'name': 'PALOMAR LA  KIMPTON HTL'}, {'price': ['197.28'], 'name': 'Residence Inn by Marriott La Mirada Buena Park'}, {'price': ['232.96'], 'name': 'Residence Inn by Marriott Los Angeles LAX Manhattan Beach'}, {'price': ['167.33'], 'name': 'TownePlace Suites by Marriott Los Angeles LAX Manhattan Beach'}, {'price': ['233.26'], 'name': 'Courtyard by Marriott Los Angeles Hacienda Heights Orange County'}, {'price': ['300.95'], 'name': 'Courtyard by Marriott Los Angeles Sherman Oaks'}, {'price': ['178.18'], 'name': 'Fairfield Inn by Marriott Santa Clarita Valencia'}, {'price': ['218.47'], 'name': 'HLTN GRDN INN LAX REDONDO BCH'}, {'price': ['228.39'], 'name': 'HOMEWOOD STES AGOURA HILLS'}, {'price': ['184.79'], 'name': 'HOLIDAY INN EXP STES FRAZIER P'}, {'price': ['225.43'], 'name': 'HOLIDAY INN EXP LAX AIRPORT'}, {'price': ['235.78'], 'name': 'Los Angeles Airport Marriott'}, {'price': ['301.33'], 'name': 'Residence Inn by Marriott Los Angeles L.A. LIVE'}, {'price': ['265.37'], 'name': 'Courtyard by Marriott Los Angeles L.A. LIVE'}, {'price': ['169.40'], 'name': 'DBLTREE BY HILTON LA ROSEMEAD'}, {'price': ['152.24'], 'name': 'Fairfield Inn by Marriott Anaheim Hills Orange County'}, {'price': ['175.21'], 'name': 'Fairfield Inn and Suites by Marriott Los Angeles-West Covina'}, {'price': ['213.44'], 'name': 'HOLIDAY INN EXP DOWNTOWN WEST'}, {'price': ['272.94'], 'name': 'HAMPTON INN STES HERMOSA BEACH'}, {'price': ['204.40'], 'name': 'HAMPTON INN STES AGOURA HILLS'}, {'price': ['257.33'], 'name': 'Torrance Marriott Redondo Beach'}, {'price': ['223.27'], 'name': 'Residence Inn by Marriott Los Angeles LAX El Segundo'}, {'price': ['153.35'], 'name': 'Residence Inn by Marriott Anaheim Placentia Fullerton'}, {'price': ['1206.74'], 'name': 'The Ritz-Carlton Los Angeles'}, {'price': ['327.31'], 'name': 'HILTON HOTELS LONDON KENSINGTON'}, {'price': ['147.68'], 'name': 'Best Western Plus Hollywood Hills Hotel'}, {'price': ['230.88'], 'name': 'HOLIDAY INN EXPRESS VAN NUYS'}, {'price': ['212.06'], 'name': 'HAMPTON INN LAX HAWTHORNE'}, {'price': ['203171'], 'name': 'HTL WILSHIRE KIMPTON'}, {'price': ['549.95'], 'name': 'VEA Newport Beach a Marriott Resort and Spa'}, {'price': ['270.00'], 'name': 'Warner Center Marriott Woodland Hills'}, {'price': ['157.03'], 'name': 'Sheraton Gateway Los Angeles Hotel'}, {'price': ['254.42'], 'name': 'Sheraton Grand Los Angeles'},  ...
# ---------- Hotel_Agent ----------
# Here are some hotels in LAX: $[{'price': ['148.09'], 'name': 'Best Western Plus Thousand Oaks Inn'}, {'price': ['197.28'], 'name': 'Courtyard by Marriott Los Angeles Baldwin Park'}, {'price': ['312.58'], 'name': 'Courtyard by Marriott Los Angeles Century City Beverly Hills'}, {'price': ['219.50'], 'name': 'Courtyard by Marriott Los Angeles LAX Century Boulevard'}, {'price': ['178.18'], 'name': 'Courtyard by Marriott Los Angeles Pasadena Monrovia'}, {'price': ['219.61'], 'name': 'DOUBLETREE BY HILTON LOS ANGELES'}, {'price': ['214.69'], 'name': 'ES-LOS ANGELES INTL AP-SOU'}, {'price': ['210.90'], 'name': 'HILTON GARDEN INN MONTEBELLO'}, {'price': ['182.59'], 'name': 'HOLIDAY INN EXP STES WOODLAND'}, {'price': ['171.
# ---------- Budget_Agent ----------
# [FunctionExecutionResult(content='178.0', name='add', call_id='call_ZqWQDqOau78RkL6FtXc0apKc', is_error=False), FunctionExecutionResult(content='296.18', name='add', call_id='call_hzEqW9RIu9pan9SiCIcvggEt', is_error=False), FunctionExecutionResult(content='100.0', name='add', call_id='call_2f0DxPtLksCnhQLPutpTSJqj', is_error=False)]
# ---------- Budget_Agent ----------
# 178.0
# 296.18
# 100.0
# ---------- User_Proxy_Agent ----------
# warner bros studio tour and sunset exotic tour
# ---------- Budget_Agent ----------
# ### Trip Cost Breakdown
#
# #### Flights
# - **Departure Flight**: Frontier from JFK to LAX
#   - Price: $89
# - **Return Flight**: Frontier from LAX to JFK
#   - Price: $89
# **Total for Flights**: $178
#
# #### Hotel
# - **Best Western Plus Thousand Oaks Inn (3 nights)**:
#   - Price per night: $148.09
#   - Total for 3 nights: $148.09 * 3 = $444.27
#
# #### Food and Activities (Estimated)
# For an estimate of meals and activities:
# - Estimated cost for meals (3 days): $50 per day * 3 days = $150
# - Activities:
#   - Warner Bros. Studio Tour (estimated): $50
#   - Sunset Exotic Tour (estimated): $50
# **Total for Food and Activities**: $150 + $100 = $250
#
# ### Total Estimated Cost of the Trip
# | Category        | Cost        |
# |-----------------|-------------|
# | Flights         | $178        |
# | Hotel           | $444.27     |
# | Food & Activities | $250      |
# | **Total Estimated Cost** | **$872.27** |
#
# This total includes round-trip flights, accommodation for three nights, meals, and two activities during your stay in Los Angeles.
# ---------- User_Proxy_Agent ----------
# yes
# ---------- TravelPlanningAgent ----------
# Great! Here’s a summary of your trip to Los Angeles from May 13 to May 16, 2025:
#
# ### Itinerary Overview
#
# #### Day 1: May 13
# - **Flight**: Depart from JFK at 11:30 AM; arrive in LAX at 2:41 PM
# - **Hotel Check-in**: Best Western Plus Thousand Oaks Inn
# - **Lunch**: Nearby local restaurant (to be confirmed)
# - **Activity**: Warner Bros. Studio Tour
#   - **Address**: 3400 Warner Blvd, Burbank, CA 91505, USA
#   - **Link**: [Warner Bros. Studio Tour](https://maps.google.com/?cid=5258936394421029256)
# - **Dinner**: Nearby restaurant (to be confirmed)
#
# #### Day 2: May 14
# - **Breakfast at hotel** (included)
# - **Activity**: Explore more of Los Angeles or optional sightseeing
# - **Lunch**: Nearby local restaurant (to be confirmed)
# - **Activity**: Sunset Exotic Tour
#   - **Address**: 6660 Hollywood Blvd, Los Angeles, CA 90028, USA
#   - **Link**: [Sunset Exotic Tour](https://maps.google.com/?cid=16428032080358911501)
# - **Dinner**: Local dining experience (to be confirmed)
#
# #### Day 3: May 15
# - **Breakfast at hotel** (included)
# - **Free day**: Explore additional attractions or shopping
# - **Lunch**: Nearby local restaurant (to be confirmed)
# - **Dinner**: Last meal in Los Angeles at a restaurant of your choice (to be confirmed)
#
# #### Day 4: May 16
# - **Check-out from hotel**
# - **Lunch**: Quick meal or snacks
# - **Flight**: Depart from LAX at 8:50 PM; arrive at JFK at 5:30 AM on May 17
#
# ### Total Estimated Cost of the Trip
# | Category        | Cost        |
# |-----------------|-------------|
# | Flights         | $178        |
# | Hotel (3 nights) | $444.27     |
# | Food & Activities| $250       |
# | **Total Estimated Cost** | **$872.27** |
#
# Would you like to make any changes to this itinerary?
# ---------- User_Proxy_Agent ----------
# APPROVE
# TaskResult(messages=[TextMessage(source='user', models_usage=None, metadata={}, content='I live near New York City. Book me a 3 day trip in Los Angeles. I am leaving on 5/13/2025.', type='TextMessage'), TextMessage(source='TravelPlanningAgent', models_usage=RequestUsage(prompt_tokens=271, completion_tokens=163), metadata={}, content="Let's break down the trip planning into manageable tasks.\n\n### Step 1: Search for Flights\n1. Flight agent: Search for flights from New York City to Los Angeles for the departure date of 5/13/2025 and return on 5/16/2025.\n\n### Step 2: Search for Hotels\n2. Hotel agent: Search for hotels in Los Angeles for the dates of 5/13/2025 to 5/16/2025.\n\n### Step 3: Search for Excursions and Food\n3. Excursion agent: Search for activities and dining options in Los Angeles for the dates of 5/13/2025 to 5/16/2025.\n\nOnce the tasks are complete, I'll confirm the choices with you. Let's get started!", type='TextMessage'), ToolCallRequestEvent(source='Flight_Agent', models_usage=RequestUsage(prompt_tokens=359, completion_tokens=48), metadata={}, content=[FunctionCall(id='call_jTip6Iem8c5GWMGRKAUDTCgI', arguments='{"departure_date":"2025-05-13","return_date":"2025-05-16","source_airport_code":"JFK","destination_airport_code":"LAX"}', name='lookup_flight')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='Flight_Agent', models_usage=None, metadata={}, content=[FunctionExecutionResult(content='Here is the best flight from JFK to LAX:\nname: Frontier\ndeparture: 11:30 AM on Tue, May 13\narrival: 2:41 PM on Tue, May 13\nduration: 6 hr 11 min\nstops: 0\nprice: $89\nHere is the best return flight from LAX to JFK:\nname: Frontier\ndeparture: 8:50 PM on Fri, May 16\narrival: 5:30 AM on Sat, May 17\nduration: 5 hr 40 min\nstops: 0\nprice: $89\n', name='lookup_flight', call_id='call_jTip6Iem8c5GWMGRKAUDTCgI', is_error=False)], type='ToolCallExecutionEvent'), ToolCallSummaryMessage(source='Flight_Agent', models_usage=None, metadata={}, content='Here is the best flight from JFK to LAX:\nname: Frontier\ndeparture: 11:30 AM on Tue, May 13\narrival: 2:41 PM on Tue, May 13\nduration: 6 hr 11 min\nstops: 0\nprice: $89\nHere is the best return flight from LAX to JFK:\nname: Frontier\ndeparture: 8:50 PM on Fri, May 16\narrival: 5:30 AM on Sat, May 17\nduration: 5 hr 40 min\nstops: 0\nprice: $89\n', type='ToolCallSummaryMessage'), ToolCallRequestEvent(source='Hotel_Agent', models_usage=RequestUsage(prompt_tokens=457, completion_tokens=18), metadata={}, content=[FunctionCall(id='call_nwvEPGZkR02jRwbJINeCEq92', arguments='{"city_code":"LAX"}', name='lookup_hotel')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='Hotel_Agent', models_usage=None, metadata={}, content=[FunctionExecutionResult(content="Here are some hotels in LAX: $[{'price': ['148.09'], 'name': 'Best Western Plus Thousand Oaks Inn'}, {'price': ['197.28'], 'name': 'Courtyard by Marriott Los Angeles Baldwin Park'}, {'price': ['312.58'], 'name': 'Courtyard by Marriott Los Angeles Century City Beverly Hills'}, {'price': ['219.50'], 'name': 'Courtyard by Marriott Los Angeles LAX Century Boulevard'}, {'price': ['178.18'], 'name': 'Courtyard by Marriott Los Angeles Pasadena Monrovia'}, {'price': ['219.61'], 'name': 'DOUBLETREE BY HILTON LOS ANGELES'}, {'price': ['214.69'], 'name': 'ES-LOS ANGELES INTL AP-SOU'}, {'price': ['210.90'], 'name': 'HILTON GARDEN INN MONTEBELLO'}, {'price': ['182.59'], 'name': 'HOLIDAY INN EXP STES WOODLAND'}, {'price': ['171.64'], 'name': 'Residence Inn by Marriott Anaheim Hills Yorba Linda'}, {'price': ['225.26'], 'name': 'Residence Inn by Marriott Redondo Beach'}, {'price': ['252.35'], 'name': 'Residence Inn by Marriott Los Angeles Westlake Village'}, {'price': ['484.73'], 'name': 'THE RITZ-CARLTON MARINA DEL RY'}, {'price': ['196.50'], 'name': 'The Westin Los Angeles Airport'}, {'price': ['184.19'], 'name': 'Best Western Plus Carriage Inn'}, {'price': ['215.88'], 'name': 'Courtyard by Marriott Los Angeles Westside'}, ...
